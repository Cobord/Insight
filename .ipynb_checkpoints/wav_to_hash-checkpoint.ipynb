# %%
import glob
import matplotlib.pyplot as plt
from scipy.fftpack import fft
from scipy.io import wavfile # get the api
import math
from scipy.ndimage.filters import gaussian_filter1d
import numpy as np

file_list=glob.glob('wav Files/*.wav')

def periodize(signal,len_needed,current_len):
    signal_expanded=signal
    to_expand=math.ceil(len_needed/current_len)
    for i in range(to_expand-1):
        signal_expanded=np.row_stack((signal_expanded,signal))
    signal_expanded=np.ravel(signal_expanded)
    return signal_expanded[:len_needed]

def zero_interleave(fourier,desiredT,currentT,cutoff):
    fourier_expanded=fourier
    to_expand=math.ceil(desiredT/currentT)
    for i in range(to_expand-1):
        fourier_expanded=np.column_stack((fourier_expanded,np.zeros(length)))
    fourier_expanded=np.ravel(fourier_expanded)
    fourier_expanded=fourier_expanded[:cutoff]
    return fourier_expanded

def with_spectrum(filename,desiredT):
    freqs, raw_data = wavfile.read(filename) # load the data
    raw_data = raw_data.T[0]
    currentT=len(raw_data)/freqs
    len_needed=desiredT*freqs
    raw_data = periodize(raw_data,len_needed,len(raw_data))
    #raw_data = gaussian_filter1d(raw_data, len_needed/100)
    #plt.plot(raw_data,'r')
    fourier = fft(raw_data)
    length = int(len(fourier)/2)
    fourier = fourier[:length]
    fourier = fourier * [2**(-i*i) for i in range(length)]
    #fourier_expanded=zero_interleave(fourier,desiredT,currentT,1200000)
    #plt.plot(abs(fourier),'g')
    #plt.show()
    return (filename,fourier)
def with_lhs(filename,desiredT,all_hyperplanes):
    _, spectra=with_spectrum(filename,desiredT)
    ambient_dimension = len(spectra)
    return (filename,hash_point(spectra,all_hyperplanes,False))

def hash_point(point,all_hyperplanes,is_real):
    if is_real:
        pre_hashed=np.dot(all_hyperplanes,point)
        return list(map(lambda x: x>=0,pre_hashed))
    else:
        pre_hashed=np.dot(all_hyperplanes,point)-point[0]
        hashed=list(map(lambda x : [np.real(x)>=0,np.imag(x)>=0],pre_hashed))
        return [item for sublist in hashed for item in sublist]

def construct_hyperplanes(num_hyperplanes,ambient_dimension,is_real):
    all_hyperplanes=np.random.randn(num_hyperplanes,ambient_dimension-1)
    if (not is_real):
        all_hyperplanes=all_hyperplanes+1j*np.random.randn(num_hyperplanes,ambient_dimension-1)
        all_hyperplanes=np.hstack((np.ones((num_hyperplanes,1)),all_hyperplanes))
    else:
        all_hyperplanes=np.hstack((np.random.randn(num_hyperplanes,1),all_hyperplanes))
    return all_hyperplanes

def swap_and_simplify(filename,res):
    res_as_num=(np.array([int(x) for x in res])*[2**i for i in range(len(res))]).sum()
    return (res_as_num,filename)

num_points=25
_,y=with_spectrum(file_list[0],30)
all_hyperplanes=construct_hyperplanes(int(np.log2(num_points)),len(y),False)
for i in range(num_points):
    filename,res=with_lhs(file_list[i],30,all_hyperplanes)
    res_as_num,_=swap_and_simplify(filename,res)
    print(filename+": "+str(res_as_num))
    
# sc.parallelize(file_list).map(lambda file: with_lhs(file,30,all_hyperplanes))
#                           .map(lambda filename, res: swap_and_simplify(filename,res))
#                          .groupByKey()
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\scipy\io\wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)
# wav Files\aerosol-can-spray-01.wav: 18
# wav Files\aerosol-can-spray-02.wav: 137
# wav Files\aerosol-can-spray-03.wav: 18
# wav Files\aerosol-can-spray-04.wav: 235
# wav Files\aerosol-can-spray-05.wav: 237
# wav Files\aerosol-can-spray-06.wav: 18
# wav Files\air-conditioner-01.wav: 214
# wav Files\air-conditioner-02.wav: 44
# wav Files\aircraft-airliner-landing-01.wav: 237
# wav Files\aircraft-cabin-ambience-01.wav: 139
# wav Files\aircraft-cabin-ambience-02.wav: 18
# wav Files\aircraft-exterior-boarding-01.wav: 139
# wav Files\aircraft-exterior-flying-steady-01.wav: 169
# wav Files\aircraft-large-airliner-fly-by-01.wav: 2
# wav Files\aircraft-large-airliner-fly-by-02.wav: 18
# wav Files\aircraft-large-airliner-fly-over-01.wav: 18
# wav Files\aircraft-large-airliner-fly-over-02.wav: 2
# wav Files\aircraft-large-airliner-fly-over-03.wav: 147
# wav Files\aircraft-large-airliner-lift-off-01.wav: 18
# wav Files\aircraft-large-airliner-lift-off-02.wav: 3
# wav Files\aircraft-large-airliner-take-off-01.wav: 171
# wav Files\aircraft-large-airliner-take-off-02.wav: 237
# wav Files\aircraft-large-airliner-take-off-03.wav: 2
# wav Files\aircraft-mid-size-airliner-fly-by-01.wav: 139
# wav Files\aircraft-mid-size-airliner-fly-over-01.wav: 185

# %%
import glob2
glob2.glob('wav Files\*.wav')
# Out:
# ['wav Files\\aerosol-can-spray-01.wav',
#  'wav Files\\aerosol-can-spray-02.wav',
#  'wav Files\\aerosol-can-spray-03.wav',
#  'wav Files\\aerosol-can-spray-04.wav',
#  'wav Files\\aerosol-can-spray-05.wav',
#  'wav Files\\aerosol-can-spray-06.wav',
#  'wav Files\\air-conditioner-01.wav',
#  'wav Files\\air-conditioner-02.wav',
#  'wav Files\\aircraft-airliner-landing-01.wav',
#  'wav Files\\aircraft-cabin-ambience-01.wav',
#  'wav Files\\aircraft-cabin-ambience-02.wav',
#  'wav Files\\aircraft-exterior-boarding-01.wav',
#  'wav Files\\aircraft-exterior-flying-steady-01.wav',
#  'wav Files\\aircraft-large-airliner-fly-by-01.wav',
#  'wav Files\\aircraft-large-airliner-fly-by-02.wav',
#  'wav Files\\aircraft-large-airliner-fly-over-01.wav',
#  'wav Files\\aircraft-large-airliner-fly-over-02.wav',
#  'wav Files\\aircraft-large-airliner-fly-over-03.wav',
#  'wav Files\\aircraft-large-airliner-lift-off-01.wav',
#  'wav Files\\aircraft-large-airliner-lift-off-02.wav',
#  'wav Files\\aircraft-large-airliner-take-off-01.wav',
#  'wav Files\\aircraft-large-airliner-take-off-02.wav',
#  'wav Files\\aircraft-large-airliner-take-off-03.wav',
#  'wav Files\\aircraft-mid-size-airliner-fly-by-01.wav',
#  'wav Files\\aircraft-mid-size-airliner-fly-over-01.wav',
#  'wav Files\\aircraft-mid-size-airliner-fly-over-02.wav',
#  'wav Files\\aircraft-mid-size-airliner-lift-off-01.wav',
#  'wav Files\\aircraft-mid-size-airliner-lift-off-02.wav',
#  'wav Files\\aircraft-mid-size-airliner-lift-off-03.wav',
#  'wav Files\\aircraft-mid-size-airliner-take-off-01.wav',
#  'wav Files\\aircraft-mid-size-airliner-take-off-02.wav',
#  'wav Files\\aircraft-mid-size-airliner-take-off-03.wav',
#  'wav Files\\aircraft-small-airliner-fly-by-01.wav',
#  'wav Files\\aircraft-small-airliner-fly-over-01.wav',
#  'wav Files\\aircraft-small-airliner-fly-over-02.wav',
#  'wav Files\\aircraft-small-airliner-fly-over-03.wav',
#  'wav Files\\aircraft-small-airliner-take-off-01.wav',
#  'wav Files\\aircraft-small-airliner-take-off-02.wav',
#  'wav Files\\aircraft-small-commuter-plane-fly-by-01.wav',
#  'wav Files\\aircraft-small-commuter-plane-take-off-01.wav',
#  'wav Files\\aircraft-small-to-mid-airliner-fly-over-01.wav',
#  'wav Files\\aircraft-small-to-mid-airliner-fly-over-02.wav',
#  'wav Files\\aircraft-small-to-mid-airliner-take-off-01.wav',
#  'wav Files\\aircraft-taxing-interior-01.wav',
#  'wav Files\\aircraft-waiting-for-take-off-exterior-01.wav',
#  'wav Files\\airplane-toilet-ambience-01.wav',
#  'wav Files\\airplane-toilet-flush-01.wav',
#  'wav Files\\airplane-toilet-flush-02.wav',
#  'wav Files\\airplane-turbines-01.wav',
#  'wav Files\\airport-baggage-carousel-01.wav',
#  'wav Files\\airport-gate-pa-announcement-01.wav',
#  'wav Files\\airport-security-checkpoint-01.wav',
#  'wav Files\\airport-security-checkpoint-02.wav',
#  'wav Files\\airport-terminal-ambience-01.wav',
#  'wav Files\\alarm-clock-analog-ringing-01.wav',
#  'wav Files\\alarm-clock-analog-run-down-01.wav',
#  'wav Files\\alarm-clock-analog-ticking-01.wav',
#  'wav Files\\alarm-clock-analog-winding-01.wav',
#  'wav Files\\alarm-clock-electronic-beeping-01.wav',
#  'wav Files\\aluminum-can-crush-01.wav',
#  'wav Files\\aluminum-can-crush-02.wav',
#  'wav Files\\aluminum-foil-crumble-01.wav',
#  'wav Files\\aluminum-foil-crumble-02.wav',
#  'wav Files\\aluminum-foil-cut-01.wav',
#  'wav Files\\aluminum-foil-cut-02.wav',
#  'wav Files\\aluminum-foil-rustle-01.wav',
#  'wav Files\\aluminum-foil-unwrap-01.wav',
#  'wav Files\\aluminum-foil-wrap-01.wav',
#  'wav Files\\ambulance-and-fire-truck-01.wav',
#  'wav Files\\antique-car-approaching-slow-01.wav',
#  'wav Files\\antique-car-departing-01.wav',
#  'wav Files\\antique-car-idle-and-rev-01.wav',
#  'wav Files\\antique-car-idling-01.wav',
#  'wav Files\\antique-car-idling-02.wav',
#  'wav Files\\antique-car-reversing-01.wav',
#  'wav Files\\antique-tube-radio-being-tuned-01.wav',
#  'wav Files\\antique-tube-radio-being-tuned-02.wav',
#  'wav Files\\antique-tube-radio-button-01.wav',
#  'wav Files\\antique-tube-radio-frequency-buttons-01.wav',
#  'wav Files\\antique-tube-radio-pressing-buttons-01.wav',
#  'wav Files\\antique-tube-radio-static-01.wav',
#  'wav Files\\antique-tube-radio-static-02.wav',
#  'wav Files\\antique-tube-radio-static-interference-01.wav',
#  'wav Files\\antique-tube-radio-static-interference-02.wav',
#  'wav Files\\antique-tube-radio-static-steady-01.wav',
#  'wav Files\\antique-tube-radio-turn-off-01.wav',
#  'wav Files\\antique-tube-radio-turn-on-01.wav',
#  'wav Files\\applause-01.wav',
#  'wav Files\\applause-02.wav',
#  'wav Files\\atv-quad-bike-pass-by-01.wav',
#  'wav Files\\atv-quad-bikes-pass-by-fast-01.wav',
#  'wav Files\\baby-amused-01.wav',
#  'wav Files\\baby-babble-01.wav',
#  'wav Files\\baby-cooing-01.wav',
#  'wav Files\\baby-cooing-02.wav',
#  'wav Files\\baby-cooing-03.wav',
#  'wav Files\\baby-coughing-01.wav',
#  'wav Files\\baby-crying-01.wav',
#  'wav Files\\baby-crying-02.wav',
#  'wav Files\\baby-crying-03.wav',
#  'wav Files\\baby-crying-04.wav',
#  'wav Files\\baby-crying-05.wav',
#  'wav Files\\baby-crying-06.wav',
#  'wav Files\\baby-crying-07.wav',
#  'wav Files\\baby-laughing-01.wav',
#  'wav Files\\baby-laughing-02.wav',
#  'wav Files\\baby-laughing-03.wav',
#  'wav Files\\baby-mmm-01.wav',
#  'wav Files\\baby-panting-01.wav',
#  'wav Files\\baby-rattle-01.wav',
#  'wav Files\\baby-rattle-02.wav',
#  'wav Files\\baby-rattle-03.wav',
#  'wav Files\\baby-rattle-04.wav',
#  'wav Files\\baby-screaming-01.wav',
#  'wav Files\\baby-screaming-02.wav',
#  'wav Files\\baby-screaming-03.wav',
#  'wav Files\\baby-squeaky-toy-01.wav',
#  'wav Files\\baby-squeaky-toy-02.wav',
#  'wav Files\\baby-squeaky-toy-03.wav',
#  'wav Files\\baby-toy-bell-01.wav',
#  'wav Files\\baby-toy-bell-02.wav',
#  'wav Files\\baby-toy-ratcheting-long-01.wav',
#  'wav Files\\baby-toy-ratcheting-long-slow-01.wav',
#  'wav Files\\baby-toy-ratcheting-short-01.wav',
#  'wav Files\\baby-toy-ratcheting-short-fast-01.wav',
#  'wav Files\\baby-toy-ratcheting-short-slow-01.wav',
#  'wav Files\\baby-toy-rustle-01.wav',
#  'wav Files\\baby-whining-01.wav',
#  'wav Files\\baby-whining-02.wav',
#  'wav Files\\baby-whining-03.wav',
#  'wav Files\\bag-zipper-01.wav',
#  'wav Files\\bag-zipper-02.wav',
#  'wav Files\\bag-zipper-03.wav',
#  'wav Files\\bag-zipper-04.wav',
#  'wav Files\\bag-zipper-05.wav',
#  'wav Files\\balloon-blow-up-01.wav',
#  'wav Files\\balloon-blow-up-02.wav',
#  'wav Files\\balloon-deflating-01.wav',
#  'wav Files\\balloon-deflating-02.wav',
#  'wav Files\\balloon-deflating-03.wav',
#  'wav Files\\balloon-deflating-04.wav',
#  'wav Files\\balloon-twist-squeaks-01.wav',
#  'wav Files\\balloon-twist-squeaks-02.wav',
#  'wav Files\\balloon-twist-squeaks-03.wav',
#  'wav Files\\bandsaw-cutting-wood-01.wav',
#  'wav Files\\bandsaw-cutting-wood-02.wav',
#  'wav Files\\bandsaw-cutting-wood-03.wav',
#  'wav Files\\bank-lobby-ambience-01.wav',
#  'wav Files\\bank-lobby-ambience-02.wav',
#  'wav Files\\bar-ambience-01.wav',
#  'wav Files\\barn-door-slide-close-01.wav',
#  'wav Files\\barn-door-slide-open-01.wav',
#  'wav Files\\bass-drum-01.wav',
#  'wav Files\\bass-drum-02.wav',
#  'wav Files\\bathroom-faucet-01.wav',
#  'wav Files\\beach-sea-waves-01.wav',
#  'wav Files\\beep-01.wav',
#  'wav Files\\beep-02.wav',
#  'wav Files\\beep-03.wav',
#  'wav Files\\beep-04.wav',
#  'wav Files\\beep-05.wav',
#  'wav Files\\beep-06.wav',
#  'wav Files\\beep-07.wav',
#  'wav Files\\beep-long-01.wav',
#  'wav Files\\beep-long-02.wav',
#  'wav Files\\beep-long-03.wav',
#  'wav Files\\beep-long-04.wav',
#  'wav Files\\beep-low-freq-long-01.wav',
#  'wav Files\\beep-low-freq-long-02.wav',
#  'wav Files\\beep-low-freq-long-03.wav',
#  'wav Files\\beep-low-freq-long-04.wav',
#  'wav Files\\beep-low-freq-long-05.wav',
#  'wav Files\\beep-low-freq-long-06.wav',
#  'wav Files\\beep-low-freq-short-01.wav',
#  'wav Files\\beep-low-freq-short-02.wav',
#  'wav Files\\beep-low-freq-short-03.wav',
#  'wav Files\\beep-short-01.wav',
#  'wav Files\\beep-short-02.wav',
#  'wav Files\\beep-short-03.wav',
#  'wav Files\\beep-short-04.wav',
#  'wav Files\\beep-short-05.wav',
#  'wav Files\\beep-short-06.wav',
#  'wav Files\\beep-short-07.wav',
#  'wav Files\\beep-short-08.wav',
#  'wav Files\\beep-short-09.wav',
#  'wav Files\\beep-short-10.wav',
#  'wav Files\\beep-short-11.wav',
#  'wav Files\\beep-short-12.wav',
#  'wav Files\\beep-short-13.wav',
#  'wav Files\\beep-short-14.wav',
#  'wav Files\\beep-short-16.wav',
#  'wav Files\\beep-short-double-01.wav',
#  'wav Files\\beep-short-double-02.wav',
#  'wav Files\\beep-short-double-03.wav',
#  'wav Files\\beep-short-double-04.wav',
#  'wav Files\\beep-short-double-05.wav',
#  'wav Files\\beep-short-double-06.wav',
#  'wav Files\\beep-short-double-07.wav',
#  'wav Files\\beep-short-double-08.wav',
#  'wav Files\\beep-short-multiple-01.wav',
#  'wav Files\\beep-short-multiple-02.wav',
#  'wav Files\\beep-short-multiple-03.wav',
#  'wav Files\\beep-short-multiple-04.wav',
#  'wav Files\\beep-short-multiple-05.wav',
#  'wav Files\\beep-short-multiple-06.wav',
#  'wav Files\\beep-short-multiple-07.wav',
#  'wav Files\\beep-short-multiple-08.wav',
#  'wav Files\\beep-short-multiple-09.wav',
#  'wav Files\\beep-short-multiple-10.wav',
#  'wav Files\\beep-short-multiple-11.wav',
#  'wav Files\\beep-short-multiple-12.wav',
#  'wav Files\\beep-short-multiple-13.wav',
#  'wav Files\\beep-short-multiple-14.wav',
#  'wav Files\\beer-bottle-open-01.wav',
#  'wav Files\\beer-bottle-open-02.wav',
#  'wav Files\\beer-bottle-open-03.wav',
#  'wav Files\\beer-bottle-open-04.wav',
#  'wav Files\\beer-can-crush-01.wav',
#  'wav Files\\beer-can-drop-01.wav',
#  'wav Files\\beer-can-drop-02.wav',
#  'wav Files\\beer-can-open-01.wav',
#  'wav Files\\beer-can-open-02.wav',
#  'wav Files\\beer-can-open-03.wav',
#  'wav Files\\beer-can-open-04.wav',
#  'wav Files\\beer-can-set-down-01.wav',
#  'wav Files\\beer-pour-glass-01.wav',
#  'wav Files\\beer-pour-glass-02.wav',
#  'wav Files\\beer-pour-glass-03.wav',
#  'wav Files\\bees-buzzing-01.wav',
#  'wav Files\\bell-01.wav',
#  'wav Files\\bell-02.wav',
#  'wav Files\\bell-ring-01.wav',
#  'wav Files\\bell-ring-02.wav',
#  'wav Files\\belt-buckle-01.wav',
#  'wav Files\\belt-buckle-02.wav',
#  'wav Files\\belt-buckle-03.wav',
#  'wav Files\\belt-buckle-04.wav',
#  'wav Files\\beverage-can-open-01.wav',
#  'wav Files\\beverage-can-open-02.wav',
#  'wav Files\\beverage-can-open-03.wav',
#  'wav Files\\bicycle-bell-ring-01.wav',
#  'wav Files\\bicycle-bell-ring-classic-01.wav',
#  'wav Files\\bicycle-bell-ring-classic-02.wav',
#  'wav Files\\bicycle-kickstand-down-01.wav',
#  'wav Files\\bicycle-kickstand-up-01.wav',
#  'wav Files\\bicycle-mini-bell-ring-01.wav',
#  'wav Files\\bicycle-pass-by-01.wav',
#  'wav Files\\bicycle-pedal-brake-01.wav',
#  'wav Files\\bicycle-pump-01.wav',
#  'wav Files\\bicycle-pump-squeaky-01.wav',
#  'wav Files\\big-hall-ambience-01.wav',
#  'wav Files\\biplane-fly-by-01.wav',
#  'wav Files\\biplane-flying-01.wav',
#  'wav Files\\biplane-flying-02.wav',
#  'wav Files\\biplane-idle-01.wav',
#  'wav Files\\biplane-pass-by-on-runway-01.wav',
#  'wav Files\\biplane-pass-by-on-runway-02.wav',
#  'wav Files\\biplane-starting-to-move-01.wav',
#  'wav Files\\biplane-starting-to-move-02.wav',
#  'wav Files\\bird-blue-throated-macaw-01.wav',
#  'wav Files\\bird-blue-throated-macaw-02.wav',
#  'wav Files\\bird-chestnut-mandibled-toucan-01.wav',
#  'wav Files\\bird-chestnut-mandibled-toucan-02.wav',
#  'wav Files\\bird-monk-parakeet-01.wav',
#  'wav Files\\bird-monk-parakeet-02.wav',
#  'wav Files\\bird-monk-parakeet-03.wav',
#  'wav Files\\bird-singing-01.wav',
#  'wav Files\\birds-chirping-01.wav',
#  'wav Files\\birds-chirping-02.wav',
#  'wav Files\\birds-chirping-03.wav',
#  'wav Files\\bite-01.wav',
#  'wav Files\\bite-02.wav',
#  'wav Files\\blow-torch-gas-burning-01.wav',
#  'wav Files\\blow-torch-gas-burning-02.wav',
#  'wav Files\\blowing-nose-01.wav',
#  'wav Files\\blowing-nose-02.wav',
#  'wav Files\\bomb-fuse-burning-01.wav',
#  'wav Files\\bomb-fuse-burning-02.wav',
#  'wav Files\\bomb-fuse-burning-03.wav',
#  'wav Files\\bone-crack-01.wav',
#  'wav Files\\bongos-01.wav',
#  'wav Files\\bongos-02.wav',
#  'wav Files\\bongos-03.wav',
#  'wav Files\\bongos-04.wav',
#  'wav Files\\book-cover-close-01.wav',
#  'wav Files\\bottle-cap-drop-01.wav',
#  'wav Files\\bottle-cap-drop-02.wav',
#  'wav Files\\bottle-cap-set-down-01.wav',
#  'wav Files\\bottle-cap-spin-01.wav',
#  'wav Files\\bottle-cap-twist-close-01.wav',
#  'wav Files\\bottle-cap-twist-open-01.wav',
#  'wav Files\\bottle-pouring-water-down-a-drain-01.wav',
#  'wav Files\\bottle-pouring-water-into-sink-01.wav',
#  'wav Files\\bow-arrow-hit-wood-01.wav',
#  'wav Files\\bow-arrow-hit-wood-and-boing-01.wav',
#  'wav Files\\bow-arrow-swoosh-by-01.wav',
#  'wav Files\\branch-cracking-forest-path-01.wav',
#  'wav Files\\branch-cracking-thin-01.wav',
#  'wav Files\\branch-cracking-tree-01.wav',
#  'wav Files\\breaking-ice-01.wav',
#  'wav Files\\breaking-ice-02.wav',
#  'wav Files\\breaking-ice-03.wav',
#  'wav Files\\briefcase-latch-close-01.wav',
#  'wav Files\\briefcase-latch-open-01.wav',
#  'wav Files\\brook-01.wav',
#  'wav Files\\brook-02.wav',
#  'wav Files\\broom-sweeping-01.wav',
#  'wav Files\\broom-sweeping-02.wav',
#  'wav Files\\broom-sweeping-03.wav',
#  'wav Files\\brushcutter-01.wav',
#  'wav Files\\brushcutter-02.wav',
#  'wav Files\\brushing-teeth-01.wav',
#  'wav Files\\brushing-teeth-02.wav',
#  'wav Files\\bulb-horn-01.wav',
#  'wav Files\\bulb-horn-02.wav',
#  'wav Files\\burp-01.wav',
#  'wav Files\\burp-02.wav',
#  'wav Files\\burp-03.wav',
#  'wav Files\\burp-04.wav',
#  'wav Files\\bus-door-open-01.wav',
#  'wav Files\\bus-interior-ambience-01.wav',
#  'wav Files\\bus-pass-by-01.wav',
#  'wav Files\\bus-pass-by-02.wav',
#  'wav Files\\bus-turn-signal-01.wav',
#  'wav Files\\business-building-lobby-ambience-01.wav',
#  'wav Files\\business-building-lobby-ambience-02.wav',
#  'wav Files\\cabinet-door-close-01.wav',
#  'wav Files\\cabinet-door-close-02.wav',
#  'wav Files\\cabinet-door-close-03.wav',
#  'wav Files\\cabinet-door-close-04.wav',
#  'wav Files\\cabinet-door-close-05.wav',
#  'wav Files\\cabinet-door-close-06.wav',
#  'wav Files\\cabinet-door-close-07.wav',
#  'wav Files\\cabinet-door-close-08.wav',
#  'wav Files\\cabinet-door-close-09.wav',
#  'wav Files\\cabinet-door-close-10.wav',
#  'wav Files\\cabinet-door-close-11.wav',
#  'wav Files\\cabinet-door-close-12.wav',
#  'wav Files\\cabinet-door-close-13.wav',
#  'wav Files\\cabinet-door-close-14.wav',
#  'wav Files\\cabinet-door-open-01.wav',
#  'wav Files\\cabinet-door-open-02.wav',
#  'wav Files\\cabinet-door-open-03.wav',
#  'wav Files\\cabinet-door-open-04.wav',
#  'wav Files\\cabinet-door-open-05.wav',
#  'wav Files\\cabinet-door-open-06.wav',
#  'wav Files\\cable-car-pass-by-01.wav',
#  'wav Files\\cable-car-pass-by-02.wav',
#  'wav Files\\cable-car-pass-by-03.wav',
#  'wav Files\\cable-car-pass-by-with-bell-ring-01.wav',
#  'wav Files\\cable-car-pass-by-with-bell-ring-02.wav',
#  'wav Files\\cable-car-ride-on-board-01.wav',
#  'wav Files\\cafeteria-ambience-01.wav',
#  'wav Files\\camcorder-battery-insert-01.wav',
#  'wav Files\\camcorder-battery-remove-01.wav',
#  'wav Files\\camcorder-door-close-01.wav',
#  'wav Files\\camcorder-door-open-01.wav',
#  'wav Files\\camcorder-rewind-01.wav',
#  'wav Files\\camcorder-tape-eject-01.wav',
#  'wav Files\\camcorder-tape-insert-01.wav',
#  'wav Files\\camcorder-tape-insert-02.wav',
#  'wav Files\\camcorder-tape-remove-01.wav',
#  'wav Files\\camcorder-tape-remove-02.wav',
#  'wav Files\\camcorder-tape-set-down-01.wav',
#  'wav Files\\camcorder-tape-set-down-02.wav',
#  'wav Files\\camera-focus-beep-01.wav',
#  'wav Files\\camera-focus-motor-01.wav',
#  'wav Files\\camera-focus-motor-02.wav',
#  'wav Files\\camera-focus-motor-03.wav',
#  'wav Files\\camera-rapid-wind-lever-01.wav',
#  'wav Files\\camera-shutter-take-picture-01.wav',
#  'wav Files\\camera-shutter-take-picture-02.wav',
#  'wav Files\\camera-shutter-take-picture-03.wav',
#  'wav Files\\campfire-01.wav',
#  'wav Files\\candy-bag-rustle-01.wav',
#  'wav Files\\candy-bag-rustle-02.wav',
#  'wav Files\\candy-bag-rustle-03.wav',
#  'wav Files\\candy-box-open-01.wav',
#  'wav Files\\candy-box-set-down-01.wav',
#  'wav Files\\candy-box-shake-01.wav',
#  'wav Files\\candy-box-shake-02.wav',
#  'wav Files\\candy-box-tilt-01.wav',
#  'wav Files\\candy-fall-drop-01.wav',
#  'wav Files\\candy-pour-01.wav',
#  'wav Files\\candy-pour-02.wav',
#  'wav Files\\candy-wrapper-crinkle-01.wav',
#  'wav Files\\car-alarm-01.wav',
#  'wav Files\\car-arrive-and-shut-off-snow-01.wav',
#  'wav Files\\car-attempting-to-start-01.wav',
#  'wav Files\\car-attempting-to-start-02.wav',
#  'wav Files\\car-attempting-to-start-03.wav',
#  'wav Files\\car-attempting-to-start-04.wav',
#  'wav Files\\car-beeping-warning-01.wav',
#  'wav Files\\car-beeping-warning-02.wav',
#  'wav Files\\car-central-lock-01.wav',
#  'wav Files\\car-central-lock-02.wav',
#  'wav Files\\car-cigarette-lighter-01.wav',
#  'wav Files\\car-cigarette-lighter-02.wav',
#  'wav Files\\car-door-close-01.wav',
#  'wav Files\\car-door-close-02.wav',
#  'wav Files\\car-door-close-03.wav',
#  'wav Files\\car-door-close-04.wav',
#  'wav Files\\car-door-close-05.wav',
#  'wav Files\\car-door-close-06.wav',
#  'wav Files\\car-door-close-07.wav',
#  'wav Files\\car-door-getting-in-snow-01.wav',
#  'wav Files\\car-door-handle-01.wav',
#  'wav Files\\car-door-key-insert-01.wav',
#  'wav Files\\car-door-key-remove-01.wav',
#  'wav Files\\car-door-open-01.wav',
#  'wav Files\\car-door-open-02.wav',
#  'wav Files\\car-door-open-03.wav',
#  'wav Files\\car-door-warning-beep-01.wav',
#  'wav Files\\car-drive-by-fast-01.wav',
#  'wav Files\\car-driving-in-snow-slow-01.wav',
#  'wav Files\\car-driving-off-fast-01.wav',
#  'wav Files\\car-fuel-filler-flap-close-01.wav',
#  'wav Files\\car-fuel-filler-flap-open-01.wav',
#  'wav Files\\car-gasoline-cap-twist-close-01.wav',
#  'wav Files\\car-gasoline-cap-twist-open-01.wav',
#  'wav Files\\car-glove-compartment-close-01.wav',
#  'wav Files\\car-glove-compartment-open-01.wav',
#  'wav Files\\car-handbrake-01.wav',
#  'wav Files\\car-handbrake-02.wav',
#  'wav Files\\car-honk-01.wav',
#  'wav Files\\car-honk-02.wav',
#  'wav Files\\car-honk-03.wav',
#  'wav Files\\car-hood-close-01.wav',
#  'wav Files\\car-hood-release-pop-01.wav',
#  'wav Files\\car-idle-and-shut-off-01.wav',
#  'wav Files\\car-ignition-and-departure-01.wav',
#  'wav Files\\car-ignition-key-insert-01.wav',
#  'wav Files\\car-ignition-key-remove-01.wav',
#  'wav Files\\car-interior-ambience-01.wav',
#  'wav Files\\car-interior-ambience-02.wav',
#  'wav Files\\car-interior-ambience-rain-01.wav',
#  'wav Files\\car-locked-honk-01.wav',
#  'wav Files\\car-pass-by-01.wav',
#  'wav Files\\car-pass-by-02.wav',
#  'wav Files\\car-pass-by-03.wav',
#  'wav Files\\car-pass-by-04.wav',
#  'wav Files\\car-pass-by-in-snow-01.wav',
#  'wav Files\\car-pass-by-wet-road-01.wav',
#  'wav Files\\car-pass-by-wet-road-02.wav',
#  'wav Files\\car-power-window-close-01.wav',
#  'wav Files\\car-power-window-open-01.wav',
#  'wav Files\\car-reverse-and-shut-off-snow-01.wav',
#  'wav Files\\car-reversing-in-snow-01.wav',
#  'wav Files\\car-revving-01.wav',
#  'wav Files\\car-side-mirror-adjust-motor-01.wav',
#  'wav Files\\car-side-mirror-adjust-motor-02.wav',
#  'wav Files\\car-side-mirror-adjust-motor-03.wav',
#  'wav Files\\car-speeds-up-01.wav',
#  'wav Files\\car-start-and-drive-away-snow-01.wav',
#  'wav Files\\car-start-and-drive-away-snow-02.wav',
#  'wav Files\\car-start-and-idle-01.wav',
#  'wav Files\\car-start-and-reverse-away-snow-01.wav',
#  'wav Files\\car-starting-01.wav',
#  'wav Files\\car-starting-02.wav',
#  'wav Files\\car-stick-shift-movement-01.wav',
#  'wav Files\\car-trunk-close-01.wav',
#  'wav Files\\car-trunk-close-02.wav',
#  'wav Files\\car-trunk-open-01.wav',
#  'wav Files\\car-trunk-unlock-01.wav',
#  'wav Files\\car-turn-signal-01.wav',
#  'wav Files\\car-turning-in-snow-01.wav',
#  'wav Files\\car-windshield-wipers-wiping-01.wav',
#  'wav Files\\card-lock-card-swipe-01.wav',
#  'wav Files\\card-lock-card-swipe-02.wav',
#  'wav Files\\cars-drive-by-01.wav',
#  'wav Files\\cars-drive-by-02.wav',
#  'wav Files\\cars-drive-by-wet-road-01.wav',
#  'wav Files\\cars-drive-by-wet-road-02.wav',
#  'wav Files\\cartoon-sounds-bang-01.wav',
#  'wav Files\\cartoon-sounds-bang-02.wav',
#  'wav Files\\cartoon-sounds-bang-03.wav',
#  'wav Files\\cartoon-sounds-bang-04.wav',
#  'wav Files\\cartoon-sounds-bang-05.wav',
#  'wav Files\\cartoon-sounds-bell-01.wav',
#  'wav Files\\cartoon-sounds-bite-01.wav',
#  'wav Files\\cartoon-sounds-boing-01.wav',
#  'wav Files\\cartoon-sounds-boing-02.wav',
#  'wav Files\\cartoon-sounds-boing-03.wav',
#  'wav Files\\cartoon-sounds-boing-04.wav',
#  'wav Files\\cartoon-sounds-bong-01.wav',
#  'wav Files\\cartoon-sounds-bong-spring-01.wav',
#  'wav Files\\cartoon-sounds-bounce-01.wav',
#  'wav Files\\cartoon-sounds-bounce-02.wav',
#  'wav Files\\cartoon-sounds-bubbles-01.wav',
#  'wav Files\\cartoon-sounds-bubbles-02.wav',
#  'wav Files\\cartoon-sounds-bubbles-03.wav',
#  'wav Files\\cartoon-sounds-car-honk-01.wav',
#  'wav Files\\cartoon-sounds-car-honk-02.wav',
#  'wav Files\\cartoon-sounds-car-honk-03.wav',
#  'wav Files\\cartoon-sounds-chime-01.wav',
#  'wav Files\\cartoon-sounds-cranking-01.wav',
#  'wav Files\\cartoon-sounds-cranking-02.wav',
#  'wav Files\\cartoon-sounds-cruching-01.wav',
#  'wav Files\\cartoon-sounds-cruching-02.wav',
#  'wav Files\\cartoon-sounds-crumble-01.wav',
#  'wav Files\\cartoon-sounds-crumble-02.wav',
#  'wav Files\\cartoon-sounds-ding-01.wav',
#  'wav Files\\cartoon-sounds-ding-02.wav',
#  'wav Files\\cartoon-sounds-doorbell-01.wav',
#  'wav Files\\cartoon-sounds-falling-01.wav',
#  'wav Files\\cartoon-sounds-falling-02.wav',
#  'wav Files\\cartoon-sounds-gliss-01.wav',
#  'wav Files\\cartoon-sounds-gliss-02.wav',
#  'wav Files\\cartoon-sounds-hit-01.wav',
#  'wav Files\\cartoon-sounds-jumps-fast-01.wav',
#  'wav Files\\cartoon-sounds-movement-sweep-01.wav',
#  'wav Files\\cartoon-sounds-piano-gliss-down-01.wav',
#  'wav Files\\cartoon-sounds-piano-gliss-up-01.wav',
#  'wav Files\\cartoon-sounds-piano-hit-01.wav',
#  'wav Files\\cartoon-sounds-piano-hit-02.wav',
#  'wav Files\\cartoon-sounds-piano-hit-03.wav',
#  'wav Files\\cartoon-sounds-piano-hit-04.wav',
#  'wav Files\\cartoon-sounds-ping-01.wav',
#  'wav Files\\cartoon-sounds-ping-02.wav',
#  'wav Files\\cartoon-sounds-ping-03.wav',
#  'wav Files\\cartoon-sounds-police-whistle-01.wav',
#  'wav Files\\cartoon-sounds-police-whistle-02.wav',
#  'wav Files\\cartoon-sounds-pop-01.wav',
#  'wav Files\\cartoon-sounds-pops-01.wav',
#  'wav Files\\cartoon-sounds-quick-movement-01.wav',
#  'wav Files\\cartoon-sounds-slide-whistle-down-01.wav',
#  'wav Files\\cartoon-sounds-slide-whistle-down-fast-01.wav',
#  'wav Files\\cartoon-sounds-slide-whistle-down-slow-01.wav',
#  'wav Files\\cartoon-sounds-slide-whistle-misc-01.wav',
#  'wav Files\\cartoon-sounds-slide-whistle-misc-02.wav',
#  'wav Files\\cartoon-sounds-slide-whistle-pop-up-01.wav',
#  'wav Files\\cartoon-sounds-slide-whistle-up-01.wav',
#  'wav Files\\cartoon-sounds-slide-whistle-up-and-down-01.wav',
#  'wav Files\\cartoon-sounds-slide-whistle-up-and-down-02.wav',
#  'wav Files\\cartoon-sounds-slide-whistle-up-fast-01.wav',
#  'wav Files\\cartoon-sounds-slide-whistle-up-slow-01.wav',
#  'wav Files\\cartoon-sounds-slurp-01.wav',
#  'wav Files\\cartoon-sounds-slurp-02.wav',
#  'wav Files\\cartoon-sounds-slurp-03.wav',
#  'wav Files\\cartoon-sounds-slurp-04.wav',
#  'wav Files\\cartoon-sounds-slurp-05.wav',
#  'wav Files\\cartoon-sounds-snoring-01.wav',
#  'wav Files\\cartoon-sounds-spin-01.wav',
#  'wav Files\\cartoon-sounds-spring-boing-01.wav',
#  'wav Files\\cartoon-sounds-spring-boing-02.wav',
#  'wav Files\\cartoon-sounds-spring-boing-03.wav',
#  'wav Files\\cartoon-sounds-spring-boing-04.wav',
#  'wav Files\\cartoon-sounds-spring-boing-05.wav',
#  'wav Files\\cartoon-sounds-spring-boing-06.wav',
#  'wav Files\\cartoon-sounds-squeak-01.wav',
#  'wav Files\\cartoon-sounds-squeak-wood-01.wav',
#  'wav Files\\cartoon-sounds-squeaks-01.wav',
#  'wav Files\\cartoon-sounds-squeaky-horn-01.wav',
#  'wav Files\\cartoon-sounds-tietop-fast-01.wav',
#  'wav Files\\cartoon-sounds-tietop-fast-02.wav',
#  'wav Files\\cartoon-sounds-tietop-fast-03.wav',
#  'wav Files\\cartoon-sounds-tietop-fast-04.wav',
#  'wav Files\\cartoon-sounds-tietop-slow-01.wav',
#  'wav Files\\cartoon-sounds-tietop-slow-02.wav',
#  'wav Files\\cartoon-sounds-timpani-glide-01.wav',
#  'wav Files\\cartoon-sounds-timpani-glide-02.wav',
#  'wav Files\\cartoon-sounds-whip-01.wav',
#  'wav Files\\cartoon-sounds-whirl-01.wav',
#  'wav Files\\cartoon-sounds-whirl-02.wav',
#  'wav Files\\cartoon-sounds-whirl-03.wav',
#  'wav Files\\cartoon-sounds-whirl-04.wav',
#  'wav Files\\cartoon-sounds-whirl-05.wav',
#  'wav Files\\cartoon-sounds-whoopie-whistle-01.wav',
#  'wav Files\\cartoon-sounds-whoopie-whistle-02.wav',
#  'wav Files\\cartoon-sounds-whoopie-whistle-03.wav',
#  'wav Files\\cartoon-sounds-whoopie-whistle-04.wav',
#  'wav Files\\cartoon-sounds-whoopie-whistle-05.wav',
#  'wav Files\\cartoon-sounds-whoosh-01.wav',
#  'wav Files\\cartoon-sounds-whoosh-02.wav',
#  'wav Files\\cartoon-sounds-whoosh-03.wav',
#  'wav Files\\cartoon-sounds-xylophone-ascend-fast-01.wav',
#  'wav Files\\cartoon-sounds-xylophone-ascend-fast-02.wav',
#  'wav Files\\cartoon-sounds-xylophone-ascend-slow-01.wav',
#  'wav Files\\cartoon-sounds-xylophone-ascend-slow-02.wav',
#  'wav Files\\cartoon-sounds-xylophone-descend-fast-01.wav',
#  'wav Files\\cartoon-sounds-xylophone-descend-fast-02.wav',
#  'wav Files\\cartoon-sounds-xylophone-descend-slow-01.wav',
#  'wav Files\\cartoon-sounds-xylophone-descend-slow-02.wav',
#  'wav Files\\cartoon-sounds-xylophone-gliss-down-01.wav',
#  'wav Files\\cartoon-sounds-xylophone-gliss-down-02.wav',
#  'wav Files\\cartoon-sounds-xylophone-gliss-down-03.wav',
#  'wav Files\\cartoon-sounds-xylophone-gliss-up-01.wav',
#  'wav Files\\cartoon-sounds-xylophone-gliss-up-02.wav',
#  'wav Files\\cartoon-sounds-xylophone-gliss-up-03.wav',
#  'wav Files\\cartoon-sounds-zip-01.wav',
#  'wav Files\\cartoon-sounds-zip-02.wav',
#  'wav Files\\cartoon-sounds-zip-03.wav',
#  'wav Files\\cassette-case-close-01.wav',
#  'wav Files\\cassette-case-open-01.wav',
#  'wav Files\\cassette-player-button-01.wav',
#  'wav Files\\cassette-player-button-02.wav',
#  'wav Files\\cassette-player-button-03.wav',
#  'wav Files\\cassette-player-close-01.wav',
#  'wav Files\\cassette-player-tape-eject-01.wav',
#  'wav Files\\cassette-player-tape-insert-01.wav',
#  'wav Files\\cassette-player-tape-insert-and-close-01.wav',
#  'wav Files\\cassette-player-tape-remove-01.wav',
#  'wav Files\\caution-car-coming-warning-buzzer-01.wav',
#  'wav Files\\cell-phone-close-01.wav',
#  'wav Files\\cell-phone-dial-nr0.wav',
#  'wav Files\\cell-phone-dial-nr1.wav',
#  'wav Files\\cell-phone-dial-nr2.wav',
#  'wav Files\\cell-phone-dial-nr3.wav',
#  'wav Files\\cell-phone-dial-nr4.wav',
#  'wav Files\\cell-phone-dial-nr5.wav',
#  'wav Files\\cell-phone-dial-nr6.wav',
#  'wav Files\\cell-phone-dial-nr7.wav',
#  'wav Files\\cell-phone-dial-nr8.wav',
#  'wav Files\\cell-phone-dial-nr9.wav',
#  'wav Files\\cell-phone-vibration-01.wav',
#  'wav Files\\censor-beep-01.wav',
#  'wav Files\\censor-beep-02.wav',
#  'wav Files\\censor-beep-03.wav',
#  'wav Files\\censor-beep-04.wav',
#  'wav Files\\censor-beep-05.wav',
#  'wav Files\\censor-beep-06.wav',
#  'wav Files\\censor-beep-07.wav',
#  'wav Files\\censor-beep-08.wav',
#  'wav Files\\censor-beep-09.wav',
#  'wav Files\\censor-beep-10.wav',
#  'wav Files\\ceramic-jar-close-01.wav',
#  'wav Files\\ceramic-jar-close-02.wav',
#  'wav Files\\ceramic-jar-close-03.wav',
#  'wav Files\\ceramic-jar-open-01.wav',
#  'wav Files\\ceramic-jar-open-02.wav',
#  'wav Files\\chainsaw-01.wav',
#  'wav Files\\chainsaw-02.wav',
#  'wav Files\\chainsaw-03.wav',
#  'wav Files\\chainsaw-04.wav',
#  'wav Files\\chainsaw-05.wav',
#  'wav Files\\chainsaw-06.wav',
#  'wav Files\\chainsaw-starter-rope-pulls-01.wav',
#  'wav Files\\chair-scraping-floor-01.wav',
#  'wav Files\\chair-scraping-floor-02.wav',
#  'wav Files\\chair-scraping-floor-03.wav',
#  'wav Files\\chair-scraping-floor-04.wav',
#  'wav Files\\chair-scraping-floor-05.wav',
#  'wav Files\\chair-scraping-floor-06.wav',
#  'wav Files\\chair-scraping-floor-07.wav',
#  'wav Files\\champagne-cork-pop-01.wav',
#  'wav Files\\champagne-cork-pop-02.wav',
#  'wav Files\\champagne-cork-pop-03.wav',
#  'wav Files\\champagne-cork-pop-04.wav',
#  'wav Files\\champagne-glass-clink-01.wav',
#  'wav Files\\champagne-glass-clink-02.wav',
#  'wav Files\\champagne-pop-pour-01.wav',
#  'wav Files\\champagne-pour-01.wav',
#  'wav Files\\champagne-set-down-01.wav',
#  'wav Files\\chinese-temple-gong-01.wav',
#  'wav Files\\chinese-temple-gong-02.wav',
#  'wav Files\\chinese-temple-gong-03.wav',
#  'wav Files\\chinese-temple-gong-04.wav',
#  'wav Files\\chinese-temple-gong-05.wav',
#  'wav Files\\christmas-handbell-01.wav',
#  'wav Files\\christmas-handbells-01.wav',
#  'wav Files\\church-bell-01.wav',
#  'wav Files\\church-bell-02.wav',
#  'wav Files\\church-bell-chiming-twice-01.wav',
#  'wav Files\\church-bell-tolling-01.wav',
#  'wav Files\\city-ambience-01.wav',
#  'wav Files\\city-ambience-02.wav',
#  'wav Files\\city-rooftop-ambience-01.wav',
#  'wav Files\\clearing-throat-01.wav',
#  'wav Files\\clearing-throat-02.wav',
#  'wav Files\\clearing-throat-03.wav',
#  'wav Files\\clock-chiming-01.wav',
#  'wav Files\\clock-chiming-02.wav',
#  'wav Files\\clock-small-ticking-01.wav',
#  'wav Files\\clock-small-ticking-02.wav',
#  'wav Files\\clock-ticking-fast-01.wav',
#  'wav Files\\clock-tolling-01.wav',
#  'wav Files\\clock-tolling-02.wav',
#  'wav Files\\closet-door-close-01.wav',
#  'wav Files\\closet-door-close-02.wav',
#  'wav Files\\closet-door-close-03.wav',
#  'wav Files\\closet-door-close-04.wav',
#  'wav Files\\closet-door-close-05.wav',
#  'wav Files\\closet-door-close-06.wav',
#  'wav Files\\closet-door-open-01.wav',
#  'wav Files\\closet-door-open-02.wav',
#  'wav Files\\closet-door-open-03.wav',
#  'wav Files\\closet-door-open-04.wav',
#  'wav Files\\closet-door-open-05.wav',
#  'wav Files\\closet-door-open-06.wav',
#  'wav Files\\cloth-roll-towel-01.wav',
#  'wav Files\\cloth-roll-towel-02.wav',
#  'wav Files\\cloth-rustle-01.wav',
#  'wav Files\\cloth-rustle-02.wav',
#  'wav Files\\coffee-beans-pour-01.wav',
#  'wav Files\\coffee-beans-pour-02.wav',
#  'wav Files\\coffee-cup-set-down-01.wav',
#  'wav Files\\coffee-cup-set-down-02.wav',
#  'wav Files\\coffee-grinder-01.wav',
#  'wav Files\\coffee-grinder-02.wav',
#  'wav Files\\coffee-grinder-03.wav',
#  'wav Files\\coffee-grinder-04.wav',
#  'wav Files\\coffee-grinder-05.wav',
#  'wav Files\\coffee-maker-brewing-01.wav',
#  'wav Files\\coffee-maker-brewing-02.wav',
#  'wav Files\\coffee-maker-switch-01.wav',
#  'wav Files\\coffee-maker-switch-02.wav',
#  'wav Files\\coffee-maker-switch-03.wav',
#  'wav Files\\coffee-maker-switch-04.wav',
#  'wav Files\\coffee-pot-pick-up-01.wav',
#  'wav Files\\coffee-pot-set-down-01.wav',
#  'wav Files\\coffee-shop-ambience-01.wav',
#  'wav Files\\coffee-shop-ambience-02.wav',
#  'wav Files\\coffee-spoon-pick-up-01.wav',
#  'wav Files\\coffee-spoon-set-down-01.wav',
#  'wav Files\\coffee-spoon-set-down-02.wav',
#  'wav Files\\coin-bag-emptying-01.wav',
#  'wav Files\\coin-bag-emptying-02.wav',
#  'wav Files\\coin-bag-filling-01.wav',
#  'wav Files\\coin-bag-pick-up-01.wav',
#  'wav Files\\coin-bag-pick-up-02.wav',
#  'wav Files\\coin-bag-set-down-01.wav',
#  'wav Files\\coin-bag-set-down-02.wav',
#  'wav Files\\coin-drop-01.wav',
#  'wav Files\\coin-spinning-01.wav',
#  'wav Files\\coin-spinning-02.wav',
#  'wav Files\\coins-collecting-01.wav',
#  'wav Files\\coins-collecting-02.wav',
#  'wav Files\\coins-collecting-03.wav',
#  'wav Files\\coins-collecting-04.wav',
#  'wav Files\\coins-collecting-05.wav',
#  'wav Files\\coins-collecting-06.wav',
#  'wav Files\\coins-drop-01.wav',
#  'wav Files\\coins-drop-02.wav',
#  'wav Files\\coins-drop-03.wav',
#  'wav Files\\coins-drop-04.wav',
#  'wav Files\\coins-drop-05.wav',
#  'wav Files\\coins-drop-06.wav',
#  'wav Files\\coins-drop-07.wav',
#  'wav Files\\coins-emptying-hand-01.wav',
#  'wav Files\\coins-emptying-hand-02.wav',
#  'wav Files\\coins-emptying-hand-03.wav',
#  'wav Files\\coins-in-hand-01.wav',
#  'wav Files\\coins-in-hand-02.wav',
#  'wav Files\\coins-in-hand-03.wav',
#  'wav Files\\coins-pick-up-01.wav',
#  'wav Files\\coins-pick-up-02.wav',
#  'wav Files\\coins-pick-up-03.wav',
#  'wav Files\\coins-pick-up-04.wav',
#  'wav Files\\coins-pick-up-05.wav',
#  'wav Files\\colored-pencil-coloring-01.wav',
#  'wav Files\\colored-pencil-coloring-02.wav',
#  'wav Files\\colored-pencil-coloring-fast-01.wav',
#  'wav Files\\colored-pencil-coloring-fast-02.wav',
#  'wav Files\\colored-pencil-coloring-slow-01.wav',
#  'wav Files\\colored-pencil-coloring-slow-02.wav',
#  'wav Files\\combine-harvester-operating-01.wav',
#  'wav Files\\comical-sounds-ascend-ding-slide-crash-01.wav',
#  'wav Files\\comical-sounds-bang-crash-whistle-01.wav',
#  'wav Files\\comical-sounds-bang-toot-descend-01.wav',
#  'wav Files\\comical-sounds-bang-toot-glide-01.wav',
#  'wav Files\\comical-sounds-boing-01.wav',
#  'wav Files\\comical-sounds-boing-02.wav',
#  'wav Files\\comical-sounds-boings-01.wav',
#  'wav Files\\comical-sounds-bong-whistle-crash-01.wav',
#  'wav Files\\comical-sounds-bong-whistle-ding-01.wav',
#  'wav Files\\comical-sounds-comic-bang-01.wav',
#  'wav Files\\comical-sounds-comic-whistle-01.wav',
#  'wav Files\\comical-sounds-crash-and-whistle-01.wav',
#  'wav Files\\comical-sounds-crash-whistles-toot-01.wav',
#  'wav Files\\comical-sounds-crash-with-brass-fall-01.wav',
#  'wav Files\\comical-sounds-drum-roll-whistle-crash-01.wav',
#  'wav Files\\comical-sounds-falling-bongs-and-boing-01.wav',
#  'wav Files\\comical-sounds-fart-toot-flute-01.wav',
#  'wav Files\\comical-sounds-fart-toot-slide-descend-01.wav',
#  'wav Files\\comical-sounds-flute-01.wav',
#  'wav Files\\comical-sounds-mix-01.wav',
#  'wav Files\\comical-sounds-rubber-squeak-01.wav',
#  'wav Files\\comical-sounds-rubber-squeak-02.wav',
#  'wav Files\\comical-sounds-rubber-squeak-03.wav',
#  'wav Files\\comical-sounds-slide-and-bang-01.wav',
#  'wav Files\\comical-sounds-slide-and-boing-01.wav',
#  'wav Files\\comical-sounds-slide-and-bongs-01.wav',
#  'wav Files\\comical-sounds-slide-and-crash-01.wav',
#  'wav Files\\comical-sounds-slide-and-cymbal-01.wav',
#  'wav Files\\comical-sounds-slide-crash-and-boing-01.wav',
#  'wav Files\\comical-sounds-slide-down-and-up-01.wav',
#  'wav Files\\comical-sounds-slide-down-and-up-02.wav',
#  'wav Files\\comical-sounds-slide-down-crash-boing-01.wav',
#  'wav Files\\comical-sounds-slide-up-and-down-01.wav',
#  'wav Files\\comical-sounds-slide-up-and-down-02.wav',
#  'wav Files\\comical-sounds-slide-up-and-down-03.wav',
#  'wav Files\\comical-sounds-squeak-and-boing-01.wav',
#  'wav Files\\comical-sounds-toot-01.wav',
#  'wav Files\\comical-sounds-toot-02.wav',
#  'wav Files\\comical-sounds-toot-03.wav',
#  'wav Files\\comical-sounds-toot-boing-whistle-01.wav',
#  'wav Files\\comical-sounds-whistle-and-boing-01.wav',
#  'wav Files\\comical-sounds-whistle-bang-crash-01.wav',
#  'wav Files\\comical-sounds-whistle-crash-boing-01.wav',
#  'wav Files\\comical-sounds-whistle-toot-bong-crash-01.wav']
